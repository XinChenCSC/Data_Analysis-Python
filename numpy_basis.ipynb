# %%
import numpy as np

from matplotlib import pyplot as plt

# %%
arr_1d = np.array([1,2,3])
arr_1d
# Out:
# array([1, 2, 3])

# %%
arr_2d = np.array([[1,2,3],[4,5,6]])
arr_2d
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr_type = np.array([1,'a',3.3,])

# %%
arr_type
# Out:
# array(['1', 'a', '3.3'], dtype='<U32')

# %%
img_url = "https://www.pngmart.com/files/15/Cat-Vector-PNG-Clipart-322x279.png"
img_arr = plt.imread(img_url)
plt.imshow(img_arr)
# Out:
# /var/folders/ks/g2159n7x159d3cpvjvhq70d40000gn/T/ipykernel_8837/4240092510.py:2: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``PIL.Image.open(urllib.request.urlopen(url))``.
#   img_arr = plt.imread(img_url)

# %%
plt.imshow(img_arr - 1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
